# %%
from langgraph.graph import StateGraph, START, END
from langchain_openai import ChatOpenAI
from typing import TypedDict
from dotenv import load_dotenv

# %%
load_dotenv()
model = ChatOpenAI()

# %%
class LLMState(TypedDict): 
    question: str 
    answer: str

# %%
def llm_qa(state: LLMState) -> LLMState:
    # Extract question from state 
    question = state['question']
    # Form a prompt
    prompt = f'Answer the following question {question}'
    # Ask LLM and get response
    answer = model.invoke(prompt).content
    
    # Update state with answer
    state['answer'] = answer
    
    return state

# %%
# Create graph instance 
graph = StateGraph(LLMState)
# Add single node 
graph.add_node('llm_qa', llm_qa)
# Define workflow path 
graph.add_edge(START, 'llm_qa') 
graph.add_edge('llm_qa', END)
# Compile the workflow 
workflow = graph.compile()

# %%
# Define initial state
initial_state = {'question': 'How far is moon from the earth?'}

# %%
# Execute workflow
final_state = workflow.invoke(initial_state)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# File D:\BJIT\LangGraph\myenv\Lib\site-packages\langchain_openai\chat_models\base.py:1904, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1903 else:
# -> 1904     raw_response = self.client.with_raw_response.create(**payload)
#    1905     response = raw_response.parse()
#
# File D:\BJIT\LangGraph\myenv\Lib\site-packages\openai\_legacy_response.py:369, in to_raw_response_wrapper.<locals>.wrapped(*args, **kwargs)
#     367 kwargs["extra_headers"] = extra_headers
# --> 369 return cast(LegacyAPIResponse[R], func(*args, **kwargs))
#
# File D:\BJIT\LangGraph\myenv\Lib\site-packages\openai\_utils\_utils.py:298, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     297     raise TypeError(msg)
# --> 298 return func(*args, **kwargs)
#
# File D:\BJIT\LangGraph\myenv\Lib\site-packages\openai\resources\chat\completions\completions.py:1308, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, moderation, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_options, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1307 validate_response_format(response_format)
# -> 1308 return self._post(
#    1309     "/chat/completions",
#    1310     body=maybe_transform(
#    1311         {
#    1312             "messages": messages,
#    1313             "model": model,
#    1314             "audio": audio,
#    1315             "frequency_penalty": frequency_penalty,
#    1316             "function_call": function_call,
#    1317             "functions": functions,
#    1318             "logit_bias": logit_bias,
#    1319             "logprobs": logprobs,
#    1320             "max_completion_tokens": max_completion_tokens,
#    1321             "max_tokens": max_tokens,
#    1322             "metadata": metadata,
#    1323             "modalities": modalities,
#    1324             "moderation": moderation,
#    1325             "n": n,
#    1326             "parallel_tool_calls": parallel_tool_calls,
#    1327             "prediction": prediction,
#    1328             "presence_penalty": presence_penalty,
#    1329             "prompt_cache_key": prompt_cache_key,
#    1330             "prompt_cache_options": prompt_cache_options,
#    1331             "prompt_cache_retention": prompt_cache_retention,
#    1332             "reasoning_effort": reasoning_effort,
#    1333             "response_format": response_format,
#    1334             "safety_identifier": safety_identifier,
#    1335             "seed": seed,
#    1336             "service_tier": service_tier,
#    1337             "stop": stop,
#    1338             "store": store,
#    1339             "stream": stream,
#    1340             "stream_options": stream_options,
#    1341             "temperature": temperature,
#    1342             "tool_choice": tool_choice,
#    1343             "tools": tools,
#    1344             "top_logprobs": top_logprobs,
#    1345             "top_p": top_p,
#    1346             "user": user,
#    1347             "verbosity": verbosity,
#    1348             "web_search_options": web_search_options,
#    1349         },
#    1350         completion_create_params.CompletionCreateParamsStreaming
#    1351         if stream
#    1352         else completion_create_params.CompletionCreateParamsNonStreaming,
#    1353     ),
#    1354     options=make_request_options(
#    1355         extra_headers=extra_headers,
#    1356         extra_query=extra_query,
#    1357         extra_body=extra_body,
#    1358         timeout=timeout,
#    1359         security={"bearer_auth": True},
#    1360     ),
#    1361     cast_to=ChatCompletion,
#    1362     stream=stream or False,
#    1363     stream_cls=Stream[ChatCompletionChunk],
#    1364 )
#
# File D:\BJIT\LangGraph\myenv\Lib\site-packages\openai\_base_client.py:1368, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1365 opts = FinalRequestOptions.construct(
#    1366     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1367 )
# -> 1368 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File D:\BJIT\LangGraph\myenv\Lib\site-packages\openai\_base_client.py:1141, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1140     log.debug("Re-raising status error")
# -> 1141     raise self._make_status_error_from_response(err.response) from None
#    1143 break
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You have no credits remaining. Add credits to continue using the API at https://platform.openai.com/settings/organization/billing/.', 'type': 'insufficient_quota', 'param': None, 'code': 'credit_balance_exhausted'}}
#
# The above exception was the direct cause of the following exception:
#
# OpenAIRateLimitError                      Traceback (most recent call last)
# Cell In[9], line 2
#       1 # Execute workflow
# ----> 2 final_state = workflow.invoke(initial_state)
#
# File D:\BJIT\LangGraph\myenv\Lib\site-packages\langgraph\pregel\main.py:3913, in Pregel.invoke(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, control, version, **kwargs)
#    3910             chunks.append(chunk)
#    3911 else:
#    3912     # v1: collect interrupts from updates stream
# -> 3913     for chunk in self.stream(
#    3914         input,
#    3915         config,
#    3916         context=context,
#    3917         stream_mode=(
#    3918             ["updates", "values"] if stream_mode == "values" else stream_mode
#    3919         ),
#    3920         print_mode=print_mode,
#    3921         output_keys=output_keys,
#    3922         interrupt_before=interrupt_before,
#    3923         interrupt_after=interrupt_after,
#    3924         durability=durability,
#    3925         control=control,
#    3926         **kwargs,
#    3927     ):
#    3928         if stream_mode == "values":
#    3929             if len(chunk) == 2:
#
# File D:\BJIT\LangGraph\myenv\Lib\site-packages\langgraph\pregel\main.py:2967, in Pregel.stream(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, control, subgraphs, debug, version, **kwargs)
#    2965 for task in loop.match_cached_writes():
#    2966     loop.output_writes(task.id, task.writes, cached=True)
# -> 2967 for _ in runner.tick(
#    2968     [t for t in loop.tasks.values() if not t.writes],
#    2969     timeout=self.step_timeout,
#    2970     get_waiter=get_waiter,
#    2971     schedule_task=loop.accept_push,
#    2972 ):
#    2973     # emit output
#    2974     yield from _output(
#    2975         stream_mode,
#    2976         print_mode,
#    (...)   2982         _state_mapper,
#    2983     )
#    2984 loop.after_tick()
#
# File D:\BJIT\LangGraph\myenv\Lib\site-packages\langgraph\pregel\_runner.py:207, in PregelRunner.tick(self, tasks, reraise, timeout, retry_policy, get_waiter, schedule_task)
#     205 scheduled_error_handler = False
#     206 try:
# --> 207     run_with_retry(
#     208         t,
#     209         retry_policy,
#     210         configurable={
#     211             CONFIG_KEY_CALL: partial(
#     212                 _call,
#     213                 weakref.ref(t),
#     214                 retry_policy=retry_policy,
#     215                 futures=weakref.ref(futures),
#     216                 schedule_task=schedule_task,
#     217                 submit=self.submit,
#     218             ),
#     219         },
#     220     )
#     221     self.commit(t, None)
#     222 except Exception as exc:
#
# File D:\BJIT\LangGraph\myenv\Lib\site-packages\langgraph\pregel\_retry.py:617, in run_with_retry(task, retry_policy, configurable)
#     615     task.writes.clear()
#     616     # run the task
# --> 617     return task.proc.invoke(task.input, config)
#     618 except ParentCommand as exc:
#     619     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File D:\BJIT\LangGraph\myenv\Lib\site-packages\langgraph\_internal\_runnable.py:707, in RunnableSeq.invoke(self, input, config, **kwargs)
#     705     # run in context
#     706     with set_config_context(config, run) as context:
# --> 707         input = context.run(step.invoke, input, config, **kwargs)
#     708 else:
#     709     input = step.invoke(input, config)
#
# File D:\BJIT\LangGraph\myenv\Lib\site-packages\langgraph\_internal\_runnable.py:447, in RunnableCallable.invoke(self, input, config, **kwargs)
#     445         run_manager.on_chain_end(ret)
#     446 else:
# --> 447     ret = self.func(*args, **kwargs)
#     448 if self.recurse and isinstance(ret, Runnable):
#     449     return ret.invoke(input, config)
#
# Cell In[6], line 7, in llm_qa(state)
#       3     question = state['question']
#       4     # Form a prompt
#       5     prompt = f'Answer the following question {question}'
#       6     # Ask LLM and get response
# ----> 7     answer = model.invoke(prompt).content
#       8
#       9     # Update state with answer
#      10     state['answer'] = answer
#
# File D:\BJIT\LangGraph\myenv\Lib\site-packages\langchain_core\language_models\chat_models.py:488, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     474 @override
#     475 def invoke(
#     476     self,
#    (...)    481     **kwargs: Any,
#     482 ) -> AIMessage:
#     483     config = ensure_config(config)
#     484     return cast(
#     485         "AIMessage",
#     486         cast(
#     487             "ChatGeneration",
# --> 488             self.generate_prompt(
#     489                 [self._convert_input(input)],
#     490                 stop=stop,
#     491                 callbacks=config.get("callbacks"),
#     492                 tags=config.get("tags"),
#     493                 metadata=config.get("metadata"),
#     494                 run_name=config.get("run_name"),
#     495                 run_id=config.pop("run_id", None),
#     496                 **kwargs,
#     497             ).generations[0][0],
#     498         ).message,
#     499     )
#
# File D:\BJIT\LangGraph\myenv\Lib\site-packages\langchain_core\language_models\chat_models.py:1877, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1868 @override
#    1869 def generate_prompt(
#    1870     self,
#    (...)   1874     **kwargs: Any,
#    1875 ) -> LLMResult:
#    1876     prompt_messages = [p.to_messages() for p in prompts]
# -> 1877     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File D:\BJIT\LangGraph\myenv\Lib\site-packages\langchain_core\language_models\chat_models.py:1684, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1681 for i, m in enumerate(input_messages):
#    1682     try:
#    1683         results.append(
# -> 1684             self._generate_with_cache(
#    1685                 m,
#    1686                 stop=stop,
#    1687                 run_manager=run_managers[i] if run_managers else None,
#    1688                 **kwargs,
#    1689             )
#    1690         )
#    1691     except BaseException as e:
#    1692         if run_managers:
#
# File D:\BJIT\LangGraph\myenv\Lib\site-packages\langchain_core\language_models\chat_models.py:2022, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    2020     result = generate_from_stream(iter(chunks))
#    2021 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 2022     result = self._generate(
#    2023         messages, stop=stop, run_manager=run_manager, **kwargs
#    2024     )
#    2025 else:
#    2026     result = self._generate(messages, stop=stop, **kwargs)
#
# File D:\BJIT\LangGraph\myenv\Lib\site-packages\langchain_openai\chat_models\base.py:1909, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1907     _handle_openai_bad_request(e)
#    1908 except openai.APIError as e:
# -> 1909     _handle_openai_api_error(e)
#    1910 except Exception as e:
#    1911     if raw_response is not None and hasattr(raw_response, "http_response"):
#
# File D:\BJIT\LangGraph\myenv\Lib\site-packages\langchain_openai\chat_models\base.py:668, in _handle_openai_api_error(e)
#     664     raise OpenAIModelNotFoundError(
#     665         message=e.message, response=e.response, body=e.body
#     666     ) from e
#     667 if isinstance(e, openai.RateLimitError):
# --> 668     raise OpenAIRateLimitError(
#     669         message=e.message, response=e.response, body=e.body
#     670     ) from e
#     671 if isinstance(e, openai.InternalServerError):
#     672     raise OpenAIAPIError(message=e.message, response=e.response, body=e.body) from e
#
# OpenAIRateLimitError: Error code: 429 - {'error': {'message': 'You have no credits remaining. Add credits to continue using the API at https://platform.openai.com/settings/organization/billing/.', 'type': 'insufficient_quota', 'param': None, 'code': 'credit_balance_exhausted'}}
# During task with name 'llm_qa' and id '7fa44e8b-7a6e-dc15-e542-ea74f900cb81'
