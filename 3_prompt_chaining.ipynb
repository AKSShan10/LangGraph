# %%
from langgraph.graph import StateGraph, START, END
from langchain_openai import ChatOpenAI
from langchain.chat_models import init_chat_model
from typing import TypedDict
from dotenv import load_dotenv

# %%
load_dotenv()
model = init_chat_model(model="gemini-3.5-flash-lite", model_provider="google_genai")

# %%
class BlogState(TypedDict):

    title: str
    outline: str
    content: str

# %%
def create_outline(state: BlogState) -> BlogState:

    # fetch title
    title = state['title']

    # call llm gen outline
    prompt = f'Generate a detailed outline for a blog on the topic - {title}'
    outline = model.invoke(prompt).content

    # update state
    state['outline'] = outline

    return state

# %%
def create_blog(state: BlogState) -> BlogState:

    title = state['title']
    outline = state['outline']

    prompt = f'Write a detailed blog on the title - {title} using the follwing outline \n {outline}'

    content = model.invoke(prompt).content

    state['content'] = content

    return state

# %%
graph = StateGraph(BlogState)

# nodes
graph.add_node('create_outline', create_outline)
graph.add_node('create_blog', create_blog)

# edges
graph.add_edge(START, 'create_outline')
graph.add_edge('create_outline', 'create_blog')
graph.add_edge('create_blog', END)

workflow = graph.compile()

# %%
intial_state = {'title': 'Rise of AI in Bangladesh'}

final_state = workflow.invoke(intial_state)

print(final_state)
# Out:
# Direct use of automatic function calling (AFC) in Models.generate_content is not recommended. Instead, we recommend to use AFC in Chat.send_message. Similarly, direct use of AFC in Models.generate_content_stream is not recommended. Instead, we recommend to use AFC in Chat.send_message_stream.
# {'title': 'Rise of AI in Bangladesh', 'outline': [{'type': 'text', 'text': 'Here is a detailed, SEO-friendly outline for a blog post on the **"Rise of AI in Bangladesh."** \n\n---\n\n# Blog Title Options:\n*   **The Rise of AI in Bangladesh: Transforming the Nation\'s Digital Future**\n*   **From Vision to Reality: How Artificial Intelligence is Shaping Bangladesh**\n*   **The AI Revolution in Bangladesh: Opportunities, Challenges, and the Road Ahead**\n\n---\n\n## I. Introduction\n*   **Hook:** Briefly paint a picture of Bangladesh’s rapid digital transformation (going from a low-income agrarian economy to a booming digital hub via "Digital Bangladesh" and "Smart Bangladesh 2041").\n*   **The Shift:** Introduce the sudden and massive integration of Artificial Intelligence (AI) across various sectors.\n*   **Thesis Statement:** AI is no longer a futuristic concept in Bangladesh; it is actively reshaping industries, empowering youth, solving local socio-economic challenges, and positioning the country as a rising tech player in South Asia.\n\n## II. The Catalyst: Why Now? (Enabling Factors)\n*   **Government Initiatives & Policy Support:** \n    *   Vision 2041 and the "Smart Bangladesh" agenda.\n    *   Establishment of hi-tech parks, IT incubators, and specialized AI/IoT labs.\n    *   Drafting of the National Artificial Intelligence Policy.\n*   **Demographic Dividend:** \n    *   A young, tech-savvy population eager to adopt emerging technologies.\n    *   Growth in STEM education and computer science graduates.\n*   **Infrastructure Growth:** \n    *   High-speed internet penetration (4G/5G rollout) and decreasing data costs.\n\n## III. Key Sectors Driving the AI Boom in Bangladesh\n*   **A. Readymade Garments (RMG) & Textile Industry:**\n    *   AI-powered computer vision for quality control and fabric defect detection.\n    *   Demand forecasting and supply chain optimization to maintain global competitiveness.\n*   **B. Fintech and Banking:**\n    *   Fraud detection and risk management algorithms.\n    *   AI chatbots and virtual assistants for 24/7 customer service in Bengali.\n    *   Credit scoring for the unbanked and micro-entrepreneurs.\n*   **C. Healthcare:**\n    *   AI-driven diagnostic tools (e.g., detecting diseases like tuberculosis, diabetic retinopathy, or cancer from scans).\n    *   Telemedicine platforms integrated with AI triage systems serving rural areas.\n*   **D. Agriculture (AgTech):**\n    *   AI apps for crop disease identification using smartphone cameras.\n    *   Smart farming solutions analyzing weather patterns, soil health, and optimal harvesting times.\n*   **E. Language Processing (NLP) & Localization:**\n    *   Overcoming language barriers with advanced Bengali Natural Language Processing.\n    *   Speech-to-text and text-to-speech innovations catering to the native population.\n\n## IV. The Rise of Bangladeshi AI Startups and Talent\n*   Highlighting home-grown success stories (e.g., startups working in computer vision, data analytics, and automation).\n*   The role of outsourcing: Bangladeshi software firms and freelancers providing AI/ML data annotation and model training for global giants.\n*   Academic contributions: AI research clubs and initiatives in universities like BUET, BRACU, and IUT.\n\n## V. Challenges and Roadblocks\n*   **Brain Drain:** The migration of top-tier AI talent to Western countries or remote global roles due to better pay.\n*   **Data Scarcity & Quality:** Lack of localized, structured, and digitized datasets in Bengali for training accurate models.\n*   **Infrastructure Gaps:** Unstable power grids in rural areas and the high cost of high-performance computing (GPUs).\n*   **Ethical & Regulatory Concerns:** Lack of robust data privacy laws, cybersecurity threats, and the potential for job displacement.\n\n## VI. The Future Outlook: What’s Next for Bangladesh?\n*   Predictions for the next 5–10 years (e.g., integration of AI in public services, smart cities ...

# %%
print(final_state['outline'])
# Out:
# [{'type': 'text', 'text': 'Here is a detailed, SEO-friendly outline for a blog post on the **"Rise of AI in Bangladesh."** \n\n---\n\n# Blog Title Options:\n*   **The Rise of AI in Bangladesh: Transforming the Nation\'s Digital Future**\n*   **From Vision to Reality: How Artificial Intelligence is Shaping Bangladesh**\n*   **The AI Revolution in Bangladesh: Opportunities, Challenges, and the Road Ahead**\n\n---\n\n## I. Introduction\n*   **Hook:** Briefly paint a picture of Bangladesh’s rapid digital transformation (going from a low-income agrarian economy to a booming digital hub via "Digital Bangladesh" and "Smart Bangladesh 2041").\n*   **The Shift:** Introduce the sudden and massive integration of Artificial Intelligence (AI) across various sectors.\n*   **Thesis Statement:** AI is no longer a futuristic concept in Bangladesh; it is actively reshaping industries, empowering youth, solving local socio-economic challenges, and positioning the country as a rising tech player in South Asia.\n\n## II. The Catalyst: Why Now? (Enabling Factors)\n*   **Government Initiatives & Policy Support:** \n    *   Vision 2041 and the "Smart Bangladesh" agenda.\n    *   Establishment of hi-tech parks, IT incubators, and specialized AI/IoT labs.\n    *   Drafting of the National Artificial Intelligence Policy.\n*   **Demographic Dividend:** \n    *   A young, tech-savvy population eager to adopt emerging technologies.\n    *   Growth in STEM education and computer science graduates.\n*   **Infrastructure Growth:** \n    *   High-speed internet penetration (4G/5G rollout) and decreasing data costs.\n\n## III. Key Sectors Driving the AI Boom in Bangladesh\n*   **A. Readymade Garments (RMG) & Textile Industry:**\n    *   AI-powered computer vision for quality control and fabric defect detection.\n    *   Demand forecasting and supply chain optimization to maintain global competitiveness.\n*   **B. Fintech and Banking:**\n    *   Fraud detection and risk management algorithms.\n    *   AI chatbots and virtual assistants for 24/7 customer service in Bengali.\n    *   Credit scoring for the unbanked and micro-entrepreneurs.\n*   **C. Healthcare:**\n    *   AI-driven diagnostic tools (e.g., detecting diseases like tuberculosis, diabetic retinopathy, or cancer from scans).\n    *   Telemedicine platforms integrated with AI triage systems serving rural areas.\n*   **D. Agriculture (AgTech):**\n    *   AI apps for crop disease identification using smartphone cameras.\n    *   Smart farming solutions analyzing weather patterns, soil health, and optimal harvesting times.\n*   **E. Language Processing (NLP) & Localization:**\n    *   Overcoming language barriers with advanced Bengali Natural Language Processing.\n    *   Speech-to-text and text-to-speech innovations catering to the native population.\n\n## IV. The Rise of Bangladeshi AI Startups and Talent\n*   Highlighting home-grown success stories (e.g., startups working in computer vision, data analytics, and automation).\n*   The role of outsourcing: Bangladeshi software firms and freelancers providing AI/ML data annotation and model training for global giants.\n*   Academic contributions: AI research clubs and initiatives in universities like BUET, BRACU, and IUT.\n\n## V. Challenges and Roadblocks\n*   **Brain Drain:** The migration of top-tier AI talent to Western countries or remote global roles due to better pay.\n*   **Data Scarcity & Quality:** Lack of localized, structured, and digitized datasets in Bengali for training accurate models.\n*   **Infrastructure Gaps:** Unstable power grids in rural areas and the high cost of high-performance computing (GPUs).\n*   **Ethical & Regulatory Concerns:** Lack of robust data privacy laws, cybersecurity threats, and the potential for job displacement.\n\n## VI. The Future Outlook: What’s Next for Bangladesh?\n*   Predictions for the next 5–10 years (e.g., integration of AI in public services, smart cities).\n*   The importance of upskilling the workforc ...

# %%
print(final_state['content'])
# Out:
# [{'type': 'text', 'text': '# The AI Revolution in Bangladesh: Opportunities, Challenges, and the Road Ahead\n\n## I. Introduction\n\nFor decades, the global narrative surrounding Bangladesh was tied primarily to its resilient agrarian roots and its powerhouse Readymade Garments (RMG) industry. However, a silent yet profound metamorphosis has been underway. Driven by the visionary blueprints of "Digital Bangladesh" and the ambitious horizon of "Smart Bangladesh 2041," the nation is rapidly transitioning from a low-income economy into a burgeoning digital and tech hub in South Asia. \n\nAmidst this rapid digital transformation, a new protagonist has stepped onto the stage: Artificial Intelligence (AI). \n\nOnce viewed as a distant, futuristic concept reserved for Silicon Valley labs, AI is now actively embedded in the fabric of Bangladeshi society. From predicting crop diseases in rural paddy fields to streamlining complex supply chains in Dhaka\'s garment factories, AI is reshaping industries, empowering a massive youth demographic, and solving localized socio-economic challenges. Bangladesh is no longer just a spectator in the global tech race—it is becoming an active participant.\n\n---\n\n## II. The Catalyst: Why Now? (Enabling Factors)\n\nThe sudden surge of AI in Bangladesh is not an accident. It is the result of strategic government foresight, demographic goldmines, and rapidly expanding digital infrastructure.\n\n### Government Initiatives & Policy Support\nThe Bangladeshi government has recognized that technological sovereignty is key to future economic survival. The **"Smart Bangladesh" agenda by 2041** serves as the guiding light, focusing on four pillars: Smart Citizen, Smart Government, Smart Economy, and Smart Society. To support this, the government has established hi-tech parks, specialized IT incubators, and dedicated AI and IoT labs across the country. Furthermore, the active drafting of the **National Artificial Intelligence Policy** signals a structured regulatory approach to foster innovation while ensuring ethical deployment.\n\n### Demographic Dividend\nBangladesh boasts a young, vibrant, and tech-savvy population, with over 65% of its citizens under the age of 25. This demographic is remarkably eager to adopt emerging technologies. Coupled with a massive boom in STEM education—with thousands of computer science and engineering graduates entering the workforce annually—the country has a ready-and-waiting talent pool to fuel the AI revolution.\n\n### Infrastructure Growth\nA tech revolution requires robust infrastructure. Bangladesh has made monumental leaps in this area, highlighted by near-universal 4G mobile internet penetration, the steady rollout of 5G trials, and significantly decreasing data costs. High-speed connectivity has bridged the digital divide, allowing youth in remote districts to access global AI resources, online courses, and development tools just as easily as their urban counterparts.\n\n---\n\n## III. Key Sectors Driving the AI Boom in Bangladesh\n\nAI’s impact across Bangladesh is multi-sectoral. Here is how artificial intelligence is transforming the nation\'s key industries:\n\n### A. Readymade Garments (RMG) & Textile Industry\nAs the backbone of Bangladesh’s export economy, the RMG sector faces immense pressure to maintain global competitiveness, speed, and precision. Factories are increasingly adopting **AI-powered computer vision** for automated quality control and fabric defect detection, minimizing human error and material wastage. Furthermore, AI-driven demand forecasting and supply chain optimization models help manufacturers predict global fashion trends and manage inventory efficiently.\n\n### B. Fintech and Banking\nThe financial sector in Bangladesh is undergoing a massive digital overhaul. Traditional banking is making way for mobile financial services (MFS) like bKash and Nagad. To safeguard these systems, financial institutions deploy advanced **fraud detection and ri ...
